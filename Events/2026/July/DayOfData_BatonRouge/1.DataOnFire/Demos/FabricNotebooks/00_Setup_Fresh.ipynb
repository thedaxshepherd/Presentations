# %% [markdown]
# # Setup

# %% [markdown]
# ## Install packages and import

# %%
print("Hello Setup")

# %% [markdown]
# ---
# This is a deliberately bare stub — a one-cell sentinel called via `%run 00_Setup_Fresh`
# from `2. PySpark` to confirm the Spark session is alive before continuing.
# **Used by:** `2. PySpark`
