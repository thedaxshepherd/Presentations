# %% [markdown]
# # Best Practice Analyzer

# %% [markdown]
# ## **<u>Spark Notebook</u>**
# ## **<u>Very active development - issues handled quickly</u>**
# ## Otherwise error for building semantic model
# ## High Concurrency requires !pip

# %%
# !pip install -U semantic-link-labs
# Out:
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 21, Finished, Available, Finished)
# ...
#   Using cached azure_core-1.38.0-py3-none-any.whl.metadata (47 kB)
# ...
# Using cached azure_core-1.38.0-py3-none-any.whl (217 kB)
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 2024.9.1
#     Uninstalling azure-core-2024.9.1:
#       Successfully uninstalled azure-core-2024.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# ...

# %% [markdown]
# ### Import the library and necessary packages

# %%
import sempy_labs as labs
import sempy_labs.report as rep
# Out:
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 23, Finished, Available, Finished)

# %% [markdown]
# ### Variables

# %%
__workspace = "PowerBI_FabricSummit2026"
__dataset = "Contoso10K_WithAutoDate"

# dictionary of workspace and models to skip
__skipmodels = {"PowerBI_FabricSummit2026": ["Old_Contoso10K","modelbparesults", "Contoso10K"]}
# Out:
# StatementMeta(, 096507bd-cb1d-4291-8367-9f4b0fdbd272, 5, Finished, Available, Finished)

# %% [markdown]
# ## Individual BPA

# %% [markdown]
# ### Return rules

# %%
df = labs.model_bpa_rules()
display(df)
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 2a35aa62-c8f3-431e-bf00-d7cba7b7ced2)

# %% [markdown]
# ### Subset of rules using existing rule set
# ### Can also create a DataFrame with rules

# %%
rules = labs.model_bpa_rules()

__rule_subset = rules[
    (rules['Rule Name'] == "Remove auto-date table") | 
    (rules['Rule Name'] == "Filter column values with proper syntax")
].copy()

display(__rule_subset)
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, abd728eb-3042-4723-ba7c-fbd7a6c7c6cb)

# %%
labs.run_model_bpa(
    dataset=__dataset,
    rules=__rule_subset
    )
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 8, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
# ...

# %% [markdown]
# ### Collect stats for all semantic models not excluded within a single workspace
# ### Run again to capture more data

# %%
__workspace = "PowerBI_FabricSummit2026"

# dictionary of workspace and models to skip
__skipmodels = {"PowerBI_FabricSummit2026": ["Old_Contoso10K","modelbparesults", "Contoso10K", "Contoso10K_RI", "Contoso10K_WithAutoDateXL"]}

labs.run_model_bpa_bulk(
    workspace = __workspace,
    skip_models_in_workspace = __skipmodels
    )
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 15, Finished, Available, Finished)
# ⌛ Collecting Model BPA stats for the 'Contoso10K_WithAutoDate' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 Collected Model BPA stats for the 'Contoso10K_WithAutoDate' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# ⌛ Saving the Model BPA results of the 'PowerBI_FabricSummit2026' workspace to the 'modelbparesults' within the lakehouse attached to this notebook...
# 🟢 The dataframe has been saved as the 'modelbparesults' table in the 'LakeBeach' lakehouse within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 Saved BPA results to the 'modelbparesults' delta table.
# 🟢 Bulk BPA scan complete.

# %%
labs.create_model_bpa_semantic_model()
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 16, Finished, Available, Finished)
# 🟢 The 'ModelBPA' semantic model was created within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 The 'BPAResults' table has been added to the 'ModelBPA' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 The 'modelbparesults' partition has been added to the 'BPAResults' table in the 'ModelBPA' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 The 'Capacity_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# 🟢 The 'Capacity_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'PowerBI_FabricSummit2026' workspace.
# ...

# %%
rep.create_model_bpa_report()
# Out:
# StatementMeta(, 78835b2d-e0ec-41d6-aa07-07826f45e783, 17, Finished, Available, Finished)
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/sempy/fabric/_credentials.py:239: FutureWarning: The 'type' parameter is deprecated and will be removed in a future version. Use 'item_type' instead.
#   return func(*args, **kwargs)
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/sempy/fabric/_credentials.py:239: FutureWarning: The 'type' parameter is deprecated and will be removed in a future version. Use 'item_type' instead.
#   return func(*args, **kwargs)
# 🟢 Succesfully created the 'ModelBPA' report within the 'PowerBI_FabricSummit2026' workspace.

# %%
__report = "ModelBPA"
rep.launch_report(report=__report)
# Out:
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 24, Finished, Available, Finished)
# Report()
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 25, Finished, Available, Finished)
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 26, Finished, Available, Finished)
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 27, Finished, Available, Finished)
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 28, Finished, Available, Finished)
# StatementMeta(, ed47070c-376f-438b-b8c9-77b832a5cbaf, 30, Finished, Available, Finished)
