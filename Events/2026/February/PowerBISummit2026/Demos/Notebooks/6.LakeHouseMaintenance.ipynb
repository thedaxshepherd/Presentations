# %% [markdown]
# # Run Maintenance

# %%
# !pip install semantic-link-labs

# %%
import sempy_labs as labs
import sempy_labs.lakehouse as lakehouse

# %%
lakehouse.run_table_maintenance(
    table_name ="botw_creatures",
    optimize=True,
    v_order=False,
    vacuum=True,
    retention_period='10:00:00:00',
    lakehouse="LakeBeach",
    workspace="PowerBI_FabricSummit2026"
)
