# %%
# %pip install -U semantic-link-labs --quiet
import importlib.metadata
print(f"✅ semantic-link-labs {importlib.metadata.version('semantic-link-labs')} installed")

# %%
import sempy.fabric as fabric
import sempy_labs as labs
import sempy_labs.report as rep
from sempy.relationships import find_relationships, plot_relationship_metadata
import pandas as pd

# ── Config ──────────────────────────────────────────────────────────────────
DATASET    = "SFCaseFiles"           # Semantic model name
DATASET_AD = "Trudoso10K_WithAutoDate"
DATASET_XL = "Trudoso0K_WithAutoDateXL"
DATASET_RI = "Trudoso10K_RI"
WORKSPACE    = None                    # None = current workspace

WORKSPACE_ID   = notebookutils.runtime.context["currentWorkspaceId"]
LAKEHOUSE_ID   = notebookutils.runtime.context["defaultLakehouseId"]
LAKEHOUSE_NAME = notebookutils.runtime.context["defaultLakehouseName"]
WORKSPACE_NAME = notebookutils.runtime.context["currentWorkspaceName"]

print(f"✅ Workspace    : {WORKSPACE_NAME}")
print(f"✅ Workspace ID : {WORKSPACE_ID}")
print(f"✅ Lakehouse    : {LAKEHOUSE_NAME}")
print(f"✅ Lakehouse ID : {LAKEHOUSE_ID}")
print("✅ Setup complete — the investigation begins")
