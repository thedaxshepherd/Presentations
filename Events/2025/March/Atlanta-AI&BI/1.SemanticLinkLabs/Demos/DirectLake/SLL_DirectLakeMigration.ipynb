# %% [markdown]
# ### Install the latest .whl package
#
# Check [here](https://pypi.org/project/semantic-link-labs/) to see the latest version.

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, fb96322e-2c5b-49a0-b435-5696886f01ad, 7, Finished, Available, Finished)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.9.5-py3-none-any.whl.metadata (25 kB)
# Collecting semantic-link-sempy>=0.8.5 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.9.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (3.1.1)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (13.3.5)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (8.1.2)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.0.0)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.25.0)
# Requirement already satisfied: requests>=2.25.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (2.31.0)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyspark in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.16.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.10)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.8.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (42.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyarrow>=12.0.1->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.15.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark->powerbiclient->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.21)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.43)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.8.0)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (0.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.5)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.2)
# Downloading semantic_link_labs-0.9.5-py3-none-any.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 22.4 MB/s eta 0:00:00
# Downloading semantic_link_sempy-0.9.3-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 126.2 MB/s eta 0:00:00
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 10.4 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: polib, jsonpath_ng, anytree, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.8.0
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# Successfully installed anytree-2.12.1 jsonpath_ng-1.7.0 polib-1.2.0 semantic-link-labs-0.9.5 semantic-link-sempy-0.9.3
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# ## 1. Show Semantic Link and Semantic Link Labs Installed

# %%
# %pip show semantic-link-sempy
print('\n')
# %pip show semantic-link-labs
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 5, Finished, Available, Finished)
# Name: semantic-link-sempy
# Version: 0.8.0
# Summary: Semantic link for Microsoft Fabric
# Home-page: https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-overview
# Author: Microsoft
# Author-email: semanticdatascience@service.microsoft.com
# License: proprietary and confidential
# Location: /home/trusted-service-user/cluster-env/clonedenv/lib/python3.11/site-packages
# Requires: clr-loader, graphviz, pyarrow, pythonnet, scikit-learn, setuptools, tqdm
# Required-by: semantic-link-labs
# Note: you may need to restart the kernel to use updated packages.
#
#
# Name: semantic-link-labs
# Version: 0.8.4
# Summary: Semantic Link Labs for Microsoft Fabric
# Home-page:
# Author: Microsoft Corporation
# Author-email:
# License: MIT License
# Location: /home/trusted-service-user/cluster-env/clonedenv/lib/python3.11/site-packages
# Requires: anytree, azure.mgmt.resource, jsonpath-ng, polib, powerbiclient, semantic-link-sempy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Import the library and set initial parameters

# %%
import sempy_labs as labs
from sempy_labs import migration, directlake
import sempy_labs.report as rep

dataset_name = 'Contoso10K' #Enter the import/DQ semantic model name
workspace_name = 'ATL25_DirectLake' #Enter the workspace of the import/DQ semantic model. It set to none it will use the current workspace.
new_dataset_name = 'DL_Contoso10K' #Enter the new Direct Lake semantic model name
new_dataset_workspace_name = 'ATL25_DirectLake' #Enter the workspace where the Direct Lake model will be created. If set to None it will use the current workspace.
lakehouse_name = 'ATL25_DirectLakehouse' #Enter the lakehouse to be used for the Direct Lake model. If set to None it will use the lakehouse attached to the notebook.
lakehouse_workspace_name = 'ATL25_DirectLakeMigration' #Enter the lakehouse workspace. If set to None it will use the new_dataset_workspace_name.
# Out:
# StatementMeta(, fb96322e-2c5b-49a0-b435-5696886f01ad, 9, Finished, Available, Finished)

# %% [markdown]
# ### 3. Create the [Power Query Template](https://learn.microsoft.com/power-query/power-query-template) file
#
# This encapsulates all of the semantic model's Power Query logic into a single file.

# %%
migration.create_pqt_file(dataset = dataset_name, workspace = workspace_name)
# Out:
# StatementMeta(, fb96322e-2c5b-49a0-b435-5696886f01ad, 10, Finished, Available, Finished)
# 🟢 'PowerQueryTemplate.pqt' has been created based on the 'Contoso10K' semantic model in the 'ATL25_DirectLake' workspace within the Files section of your lakehouse.

# %% [markdown]
# ### 4. Import the Power Query Template to Dataflows Gen2
#
# - Open the [OneLake file explorer](https://www.microsoft.com/download/details.aspx?id=105222) and sync your files (right click -> Sync from OneLake)
#
# - Navigate to your lakehouse. From this window, create a new Dataflows Gen2 and import the Power Query Template file from OneLake (OneLake -> Workspace -> Lakehouse -> Files...), and publish the Dataflows Gen2.
#
# <div class="alert alert-block alert-info">
# <b>Important!</b> Make sure to create the Dataflows Gen2 from within the lakehouse window. That will ensure that all the tables automatically map to that lakehouse as the destination. Otherwise, you will have to manually map each table to its destination individually.
# </div>

# %% [markdown]
# ### 5. Create the Direct Lake model based on the import/DQ semantic model
#
# Calculated columns are not migrated to the Direct Lake model as they are not supported in Direct Lake mode.

# %%
import time
labs.create_blank_semantic_model(dataset = new_dataset_name, workspace = new_dataset_workspace_name, overwrite=True)

migration.migrate_calc_tables_to_lakehouse(
    dataset = dataset_name,
    new_dataset = new_dataset_name,
    workspace = workspace_name,
    new_dataset_workspace = new_dataset_workspace_name,
    lakehouse = lakehouse_name,
    lakehouse_workspace = lakehouse_workspace_name
)
migration.migrate_tables_columns_to_semantic_model(
    dataset = dataset_name,
    new_dataset = new_dataset_name,
    workspace = workspace_name,
    new_dataset_workspace = new_dataset_workspace_name,
    lakehouse = lakehouse_name,
    lakehouse_workspace = lakehouse_workspace_name
)
migration.migrate_calc_tables_to_semantic_model(
    dataset = dataset_name,
    new_dataset = new_dataset_name,
    workspace = workspace_name,
    new_dataset_workspace = new_dataset_workspace_name,
    lakehouse = lakehouse_name,
    lakehouse_workspace = lakehouse_workspace_name
)
migration.migrate_model_objects_to_semantic_model(
    dataset = dataset_name,
    new_dataset = new_dataset_name,
    workspace = workspace_name,
    new_dataset_workspace = new_dataset_workspace_name
)
migration.migrate_field_parameters(
    dataset = dataset_name,
    new_dataset = new_dataset_name,
    workspace = workspace_name,
    new_dataset_workspace = new_dataset_workspace_name
)
time.sleep(2)
labs.refresh_semantic_model(dataset = new_dataset_name, workspace = new_dataset_workspace_name)
migration.refresh_calc_tables(dataset = new_dataset_name, workspace = new_dataset_workspace_name)
labs.refresh_semantic_model(dataset = new_dataset_name, workspace = new_dataset_workspace_name)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 8, Finished, Available, Finished)
# 🟢 The 'DL_Contoso10K' semantic model was created within the 'DirectLakeMigration' workspace.
# 🟡 The 'Contoso10K' semantic model in the 'DirectLakeMigration' workspace has no calculated tables.
# ⌛ Updating 'DL_Contoso10K' based on 'Contoso10K'...
# 🟢 The 'DatabaseQuery' expression has been added.
# 🟢 The 'Product' table has been added.
# 🟢 The 'Sales' table has been added.
# 🟢 The 'Store' table has been added.
# 🟢 The 'Date' table has been added.
# 🟢 The 'Customer' table has been added.
# 🟢 The 'Product'[ProductKey] column has been added.
# 🟢 The 'Product'[Product Code] column has been added.
# 🟢 The 'Product'[Product Name] column has been added.
# 🟢 The 'Product'[Manufacturer] column has been added.
# 🟢 The 'Product'[Brand] column has been added.
# 🟢 The 'Product'[Color] column has been added.
# 🟢 The 'Product'[Weight Unit Measure] column has been added.
# 🟢 The 'Product'[Weight] column has been added.
# 🟢 The 'Product'[Unit Cost] column has been added.
# 🟢 The 'Product'[Unit Price] column has been added.
# 🟢 The 'Product'[Subcategory Code] column has been added.
# 🟢 The 'Product'[Subcategory] column has been added.
# 🟢 The 'Product'[Category Code] column has been added.
# 🟢 The 'Product'[Category] column has been added.
# 🟢 The 'Sales'[Order Number] column has been added.
# 🟢 The 'Sales'[Line Number] column has been added.
# 🟢 The 'Sales'[Order Date] column has been added.
# 🟢 The 'Sales'[Delivery Date] column has been added.
# 🟢 The 'Sales'[CustomerKey] column has been added.
# 🟢 The 'Sales'[StoreKey] column has been added.
# 🟢 The 'Sales'[ProductKey] column has been added.
# 🟢 The 'Sales'[Quantity] column has been added.
# 🟢 The 'Sales'[Unit Price] column has been added.
# 🟢 The 'Sales'[Net Price] column has been added.
# 🟢 The 'Sales'[Unit Cost] column has been added.
# 🟢 The 'Sales'[Currency Code] column has been added.
# 🟢 The 'Sales'[Exchange Rate] column has been added.
# 🟢 The 'Sales'[OrderDateId] column has been added.
# 🟢 The 'Sales'[DeliveryDateId] column has been added.
# 🟢 The 'Store'[StoreKey] column has been added.
# 🟢 The 'Store'[Store Code] column has been added.
# 🟢 The 'Store'[Country] column has been added.
# 🟢 The 'Store'[State] column has been added.
# 🟢 The 'Store'[Name] column has been added.
# 🟢 The 'Store'[Square Meters] column has been added.
# 🟢 The 'Store'[Open Date] column has been added.
# 🟢 The 'Store'[Close Date] column has been added.
# 🟢 The 'Store'[Status] column has been added.
# 🟢 The 'Date'[Date] column has been added.
# 🟢 The 'Date'[Year] column has been added.
# 🟢 The 'Date'[Year Quarter] column has been added.
# 🟢 The 'Date'[Year Quarter Number] column has been added.
# 🟢 The 'Date'[Quarter] column has been added.
# 🟢 The 'Date'[Year Month] column has been added.
# 🟢 The 'Date'[Year Month Short] column has been added.
# 🟢 The 'Date'[Year Month Number] column has been added.
# 🟢 The 'Date'[Month] column has been added.
# 🟢 The 'Date'[Month Short] column has been added.
# 🟢 The 'Date'[Month Number] column has been added.
# 🟢 The 'Date'[Day of Week] column has been added.
# 🟢 The 'Date'[Day of Week Short] column has been added.
# 🟢 The 'Date'[Day of Week Number] column has been added.
# 🟢 The 'Date'[Working Day] column has been added.
# 🟢 The 'Date'[Working Day Number] column has been added.
# 🟢 The 'Date'[DateId] column has been added.
# 🟢 The 'Customer'[CustomerKey] column has been added.
# 🟢 The 'Customer'[Gender] column has been added.
# 🟢 The 'Customer'[Name] column has been added.
# 🟢 The 'Customer'[Address] column has been added.
# 🟢 The 'Customer'[City] column has been added.
# 🟢 The 'Customer'[State Code] column has been added.
# 🟢 The 'Customer'[State] column has been added.
# 🟢 The 'Customer'[Zip Code] column has been added.
# 🟢 The 'Customer'[Country Code] column has been added.
# 🟢 The 'Customer'[Country] column has been added.
# 🟢 The 'Customer'[Continent] column has been added.
# 🟢 The 'Customer'[Birthday] column has been added.
# 🟢 The 'Customer'[Age] column has been added.
#
# 🟢 All regular tables and columns have been added to the 'DL_Contoso10K' semantic model.
# 🟢 The 'Contoso10K' semantic model has no calculated tables.
# ⌛ Updating 'DL_Contoso10K' based on 'Contoso10K'...
#
# ⌛ Updating table properties...
# 🟢 The 'Product' table's properties have been updated.
# 🟢 The 'Sales' table's properties have been updated.
# 🟢 The 'Store' table's properties have been updated.
# 🟢 The 'Date' table's properties have been updated.
# 🟢 The 'Customer' table's properties have been updated.
#
# ⌛ Updating column properties...
# 🟢 The 'Product'[ProductKey] column's properties have been updated.
# 🟢 The 'Product'[Product Code] column's properties have been updated.
# 🟢 The 'Product'[Product Name] column's properties have been updated.
# 🟢 The 'Product'[Manufacturer] column's properties have been updated.
# 🟢 The 'Product'[Brand] column's properties have been updated.
# 🟢 The 'Product'[Color] column's properties have been updated.
# 🟢 The 'Product'[Weight Unit Measure] column's properties have been updated.
# 🟢 The 'Product'[Weight] column's properties have been updated.
# 🟢 The 'Product'[Unit Cost] column's properties have been updated.
# 🟢 The 'Product'[Unit Price] column's properties have been updated.
# 🟢 The 'Product'[Subcategory Code] column's properties have been updated.
# 🟢 The 'Product'[Subcategory] column's properties have been updated.
# 🟢 The 'Product'[Category Code] column's properties have been updated.
# 🟢 The 'Product'[Category] column's properties have been updated.
# 🟢 The 'Sales'[Order Number] column's properties have been updated.
# 🟢 The 'Sales'[Line Number] column's properties have been updated.
# 🟢 The 'Sales'[Order Date] column's properties have been updated.
# 🟢 The 'Sales'[Delivery Date] column's properties have been updated.
# 🟢 The 'Sales'[CustomerKey] column's properties have been updated.
# 🟢 The 'Sales'[StoreKey] column's properties have been updated.
# 🟢 The 'Sales'[ProductKey] column's properties have been updated.
# 🟢 The 'Sales'[Quantity] column's properties have been updated.
# 🟢 The 'Sales'[Unit Price] column's properties have been updated.
# 🟢 The 'Sales'[Net Price] column's properties have been updated.
# 🟢 The 'Sales'[Unit Cost] column's properties have been updated.
# 🟢 The 'Sales'[Currency Code] column's properties have been updated.
# 🟢 The 'Sales'[Exchange Rate] column's properties have been updated.
# 🟢 The 'Sales'[OrderDateId] column's properties have been updated.
# 🟢 The 'Sales'[DeliveryDateId] column's properties have been updated.
# 🟢 The 'Store'[StoreKey] column's properties have been updated.
# 🟢 The 'Store'[Store Code] column's properties have been updated.
# 🟢 The 'Store'[Country] column's properties have been updated.
# 🟢 The 'Store'[State] column's properties have been updated.
# 🟢 The 'Store'[Name] column's properties have been updated.
# 🟢 The 'Store'[Square Meters] column's properties have been updated.
# 🟢 The 'Store'[Open Date] column's properties have been updated.
# 🟢 The 'Store'[Close Date] column's properties have been updated.
# 🟢 The 'Store'[Status] column's properties have been updated.
# 🟢 The 'Date'[Date] column's properties have been updated.
# 🟢 The 'Date'[Year] column's properties have been updated.
# 🟢 The 'Date'[Year Quarter] column's properties have been updated.
# 🟢 The 'Date'[Year Quarter Number] column's properties have been updated.
# 🟢 The 'Date'[Quarter] column's properties have been updated.
# 🟢 The 'Date'[Year Month] column's properties have been updated.
# 🟢 The 'Date'[Year Month Short] column's properties have been updated.
# 🟢 The 'Date'[Year Month Number] column's properties have been updated.
# 🟢 The 'Date'[Month] column's properties have been updated.
# 🟢 The 'Date'[Month Short] column's properties have been updated.
# 🟢 The 'Date'[Month Number] column's properties have been updated.
# 🟢 The 'Date'[Day of Week] column's properties have been updated.
# 🟢 The 'Date'[Day of Week Short] column's properties have been updated.
# 🟢 The 'Date'[Day of Week Number] column's properties have been updated.
# 🟢 The 'Date'[Working Day] column's properties have been updated.
# 🟢 The 'Date'[Working Day Number] column's properties have been updated.
# 🟢 The 'Date'[DateId] column's properties have been updated.
# 🟢 The 'Customer'[CustomerKey] column's properties have been updated.
# 🟢 The 'Customer'[Gender] column's properties have been updated.
# 🟢 The 'Customer'[Name] column's properties have been updated.
# 🟢 The 'Customer'[Address] column's properties have been updated.
# 🟢 The 'Customer'[City] column's properties have been updated.
# 🟢 The 'Customer'[State Code] column's properties have been updated.
# 🟢 The 'Customer'[State] column's properties have been updated.
# 🟢 The 'Customer'[Zip Code] column's properties have been updated.
# 🟢 The 'Customer'[Country Code] column's properties have been updated.
# 🟢 The 'Customer'[Country] column's properties have been updated.
# 🟢 The 'Customer'[Continent] column's properties have been updated.
# 🟢 The 'Customer'[Birthday] column's properties have been updated.
# 🟢 The 'Customer'[Age] column's properties have been updated.
#
# ⌛ Creating hierarchies...
#
# ⌛ Creating measures...
# 🟢 The 'Sales Amount' measure has been added.
# 🟢 The '#Sales' measure has been added.
# 🟢 The '#LargeSales_Slow' measure has been added.
#
# ⌛ Creating calculation groups...
#
# ⌛ Creating relationships...
# 🟢 The 'Sales'[ProductKey] -> 'Product'[ProductKey] relationship has been added.
# 🟢 The 'Sales'[CustomerKey] -> 'Customer'[CustomerKey] relationship has been added.
# 🟢 The 'Sales'[StoreKey] -> 'Store'[StoreKey] relationship has been added.
# 🟢 The 'Sales'[OrderDateId] -> 'Date'[DateId] relationship has been added.
#
# ⌛ Creating roles...
#
# ⌛ Creating row level security...
#
# ⌛ Creating perspectives...
#
# ⌛ Adding objects to perspectives...
#
# ⌛ Creating translation languages...
#
# ⌛ Creating translation values...
#
# 🟢 Migration of objects from 'Contoso10K' -> 'DL_Contoso10K' is complete.
# 🟢 The 'Contoso10K' semantic model in the 'DirectLakeMigration' workspace has no field parameters.
# ⌛ Refresh of the 'DL_Contoso10K' semantic model within the 'DirectLakeMigration' workspace is in progress...
# 🟢 Refresh of the 'DL_Contoso10K' semantic model within the 'DirectLakeMigration' workspace is complete.
# ⌛ Refresh of the 'DL_Contoso10K' semantic model within the 'DirectLakeMigration' workspace is in progress...
# 🟢 Refresh of the 'DL_Contoso10K' semantic model within the 'DirectLakeMigration' workspace is complete.

# %% [markdown]
# ### 6. Show migrated/unmigrated objects

# %%
# Changed so output goes to DataFrame 
df = migration.migration_validation(
    dataset = dataset_name,
    new_dataset = new_dataset_name, 
    workspace = workspace_name, 
    new_dataset_workspace = new_dataset_workspace_name
)

display(df)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 9, Finished, Available, Finished)
# 94.0% migrated
# SynapseWidget(Synapse.DataFrame, 02fd5947-9acd-40cc-85e9-76cde34d9526)

# %% [markdown]
# ### Rebind all reports using the old semantic model to the new Direct Lake semantic model

# %%
#rep.report_rebind_all(
#    dataset = dataset_name,
#    dataset_workspace = workspace_name,
#    new_dataset = new_dataset_name,
#    new_dataset_workpace = new_dataset_workspace_name,
#    report_workspace = None
#)

# %% [markdown]
# ### 7. Rebind reports one-by-one (optional)

# %%
report_name = 'DL_Contoso10K' # Enter report name which you want to rebind to the new Direct Lake model

rep.report_rebind(
    report = report_name,
    dataset = new_dataset_name,
    report_workspace=workspace_name,
    dataset_workspace = new_dataset_workspace_name)
# Out:
# StatementMeta(, fb96322e-2c5b-49a0-b435-5696886f01ad, 11, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 report_name = 'DL_Contoso10K' # Enter report name which you want to rebind to the new Direct Lake model
# ----> 3 rep.report_rebind(
#       4     report = report_name,
#       5     dataset = new_dataset_name,
#       6     report_workspace=workspace_name,
#       7     dataset_workspace = new_dataset_workspace_name)
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy/_utils/_log.py:357, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     354 start_time = time.perf_counter()
#     356 try:
# --> 357     result = func(*args, **kwargs)
#     359     # The invocation for get_message_dict moves after the function
#     360     # so it can access the state after the method call
#     361     message.update(extractor.get_completion_message_dict(result, arg_dict))
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy_labs/report/_report_rebind.py:53, in report_rebind(report, dataset, report_workspace, dataset_workspace)
#      50     report = [report]
#      52 for rpt in report:
# ---> 53     report_id = resolve_report_id(report=rpt, workspace=report_workspace_id)
#      54     dataset_id = resolve_dataset_id(dataset=dataset, workspace=dataset_workspace)
#      56     payload = {"datasetId": dataset_id}
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy_labs/_helper_functions.py:159, in resolve_report_id(report, workspace)
#     138 def resolve_report_id(
#     139     report: str | UUID, workspace: Optional[str | UUID] = None
#     140 ) -> UUID:
#     141     """
#     142     Obtains the ID of the Power BI report.
#     143
#    (...)
#     156         The ID of the Power BI report.
#     157     """
# --> 159     return resolve_item_id(item=report, type="Report", workspace=workspace)
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy_labs/_helper_functions.py:314, in resolve_item_id(item, type, workspace)
#     312     return item
#     313 else:
# --> 314     return fabric.resolve_item_id(item_name=item, type=type, workspace=workspace)
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy/_utils/_log.py:357, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     354 start_time = time.perf_counter()
#     356 try:
# --> 357     result = func(*args, **kwargs)
#     359     # The invocation for get_message_dict moves after the function
#     360     # so it can access the state after the method call
#     361     message.update(extractor.get_completion_message_dict(result, arg_dict))
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy/fabric/_flat.py:1227, in resolve_item_id(item_name, type, workspace)
#    1200 @log
#    1201 def resolve_item_id(item_name: str, type: Optional[str] = None,
#    1202                     workspace: Optional[Union[str, UUID]] = None) -> str:
#    1203     """
#    1204     Resolve the item ID by name in the specified workspace.
#    1205
#    (...)
#    1225         The item ID of the specified item.
#    1226     """
# -> 1227     return _get_or_create_workspace_client(workspace).resolve_item_id(item_name, type=type)
#
# File /nfs4/pyenv-d603ca82-e177-438e-b5d8-2fd19a0f7141/lib/python3.11/site-packages/sempy/fabric/_client/_workspace_client.py:554, in WorkspaceClient.resolve_item_id(self, item_name, type)
#     552 selected_df = df[df["Display Name"] == item_name]["Id"]
#     553 if selected_df.empty:
# --> 554     raise ValueError(f"There's no item with the name '{item_name}' in workspace '{self.get_workspace_name()}'")
#     555 return selected_df.values[0]
#
# ValueError: There's no item with the name 'DL_Contoso10K' in workspace 'ATL25_DirectLake'

# %% [markdown]
# ### 8. Show unsupported objects

# %%
dfT, dfC, dfR = directlake.show_unsupported_direct_lake_objects(dataset = dataset_name, workspace = workspace_name)

print('Calculated Tables are not supported...')
display(dfT)
print("Learn more about Direct Lake limitations here: https://learn.microsoft.com/power-bi/enterprise/directlake-overview#known-issues-and-limitations")
print('Calculated columns are not supported. Columns of binary data type are not supported.')
display(dfC)
print('Columns used for relationship must be of the same data type.')
display(dfR)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 13, Finished, Available, Finished)
# Calculated Tables are not supported...
# SynapseWidget(Synapse.DataFrame, d10db1c9-b8a5-485a-9f85-9a09347f7f11)
# Learn more about Direct Lake limitations here: https://learn.microsoft.com/power-bi/enterprise/directlake-overview#known-issues-and-limitations
# Calculated columns are not supported. Columns of binary data type are not supported.
# SynapseWidget(Synapse.DataFrame, 9bea8618-7120-4815-b67d-63fb1e5e35d9)
# Columns used for relationship must be of the same data type.
# SynapseWidget(Synapse.DataFrame, 83bf2872-052a-4bd3-921a-11a40bcce3e1)

# %% [markdown]
# ### 9. Schema check between semantic model tables/columns and lakehouse tables/columns
#
# This will list any tables/columns which are in the new semantic model but do not exist in the lakehouse

# %%
directlake.direct_lake_schema_compare(dataset = new_dataset_name, workspace = new_dataset_workspace_name)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 14, Finished, Available, Finished)
# 🟢 All tables exist in the 'DirectLakeHouse' lakehouse within the 'DirectLakeMigration' workspace.
# 🟢 All columns exist in the 'DirectLakeHouse' lakehouse within the 'DirectLakeMigration' workspace.

# %% [markdown]
# ### 10. Show calculated tables which have been migrated to the Direct Lake semantic model as regular tables

# %%
directlake.list_direct_lake_model_calc_tables(dataset = new_dataset_name, workspace = new_dataset_workspace_name)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 15, Finished, Available, Finished)
# Empty DataFrame
# Columns: [Table Name, Source Expression]
# Index: []

# %% [markdown]
# ## 11. Display info about LakeHouse Tables

# %%
df = labs.lakehouse.get_lakehouse_tables(lakehouse = 'DirectLakeHouse', workspace= 'DirectLakeMigration', extended='true', count_rows = 'true')

display(df)
# Out:
# StatementMeta(, 238839fd-b9e5-43f7-99d3-1e588fdbe881, 16, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 04c17995-15ae-402c-9696-37ff8cdaaf8d)
