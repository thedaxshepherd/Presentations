# %% [markdown]
# # Semantic Link
#
# - More information: https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-overview

# %% [markdown]
# ## FabricDataFrame
# - Supports all pandas operations.
# - Subclasses the pandas DataFrame and adds metadata, such as semantic information and lineage.
# - Exposes semantic functions and the add-measure method that lets you use Power BI measures in data science work.
# - Can run type(df) to see what object type it is - pandas - i.e. pandas.core.frame.DataFrame

# %% [markdown]
# ## Install  Semantic Link
# ## Already installed in Python Notebook and Spark
# ## Will update to latest version

# %%
# %pip install -U semantic-link
# Out:
# Collecting semantic-link
#   Downloading semantic_link-0.12.1-py3-none-any.whl.metadata (11 kB)
# Collecting semantic-link-sempy==0.12.1 (from semantic-link)
#   Downloading semantic_link_sempy-0.12.1-py3-none-any.whl.metadata (11 kB)
# Collecting semantic-link-functions-geopandas==0.12.1 (from semantic-link)
#   Downloading semantic_link_functions_geopandas-0.12.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting semantic-link-functions-holidays==0.12.1 (from semantic-link)
#   Downloading semantic_link_functions_holidays-0.12.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-meteostat==0.12.1 (from semantic-link)
#   Downloading semantic_link_functions_meteostat-0.12.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting semantic-link-functions-phonenumbers==0.12.1 (from semantic-link)
#   Downloading semantic_link_functions_phonenumbers-0.12.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-validators==0.12.1 (from semantic-link)
#   Downloading semantic_link_functions_validators-0.12.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting geopandas (from semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting folium (from semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting mapclassify (from semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: holidays in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-functions-holidays==0.12.1->semantic-link) (0.74)
# Collecting meteostat (from semantic-link-functions-meteostat==0.12.1->semantic-link)
#   Downloading meteostat-1.7.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting phonenumbers (from semantic-link-functions-phonenumbers==0.12.1->semantic-link)
#   Downloading phonenumbers-9.0.16-py2.py3-none-any.whl.metadata (11 kB)
# Collecting validators (from semantic-link-functions-validators==0.12.1->semantic-link)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (0.2.7.post0)
# Collecting fabric-analytics-sdk==0.0.1 (from fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link)
#   Downloading fabric_analytics_sdk-0.0.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (0.20.3)
# Requirement already satisfied: azure-keyvault-secrets>=4.7.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (4.7.0)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (17.0.0)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (1.5.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (80.9.0)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (4.66.4)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (13.9.4)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (2023.12.25)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (2.32.3)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (3.11.11)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy==0.12.1->semantic-link) (9.0.0)
# Requirement already satisfied: azure-core in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (1.29.4)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (1.17.1)
# Collecting fabric-analytics-notebook-plugin (from fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link)
#   Downloading fabric_analytics_notebook_plugin-0.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.12.1->semantic-link) (1.20.0)
# Requirement already satisfied: azure-common~=1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.12.1->semantic-link) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.12.1->semantic-link) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.12.1->semantic-link) (4.14.0)
# Requirement already satisfied: cffi>=1.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy==0.12.1->semantic-link) (1.17.1)
# Requirement already satisfied: decorator in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (2.19.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (4.9.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.12.1->semantic-link) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.12.1->semantic-link) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.12.1->semantic-link) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.12.1->semantic-link) (2025.2)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy==0.12.1->semantic-link) (0.10.9.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.12.1->semantic-link) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.12.1->semantic-link) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.12.1->semantic-link) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.12.1->semantic-link) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy==0.12.1->semantic-link) (3.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.12.1->semantic-link) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.12.1->semantic-link) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.12.1->semantic-link) (3.6.0)
# Collecting branca>=0.6.0 (from folium->semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.12.1->semantic-link) (3.1.6)
# Collecting xyzservices (from folium->semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyogrio>=0.7.2 (from geopandas->semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading pyogrio-0.11.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from geopandas->semantic-link-functions-geopandas==0.12.1->semantic-link) (24.2)
# Collecting pyproj>=3.5.0 (from geopandas->semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading pyproj-3.7.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->semantic-link-functions-geopandas==0.12.1->semantic-link)
#   Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: networkx>=3.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from mapclassify->semantic-link-functions-geopandas==0.12.1->semantic-link) (3.5)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (1.16.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from cffi>=1.17->clr-loader>=0.2.5->semantic-link-sempy==0.12.1->semantic-link) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.12.1->semantic-link) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy==0.12.1->semantic-link) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.2.13)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (45.0.3)
# Requirement already satisfied: msal>=1.24.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (1.32.3)
# Requirement already satisfied: msal-extensions>=0.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (1.3.1)
# Requirement already satisfied: psutil in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (7.0.0)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (3.0.0)
# Requirement already satisfied: pure_eval in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.12.1->semantic-link) (0.2.3)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy==0.12.1->semantic-link) (2.8.0)
# Downloading semantic_link-0.12.1-py3-none-any.whl (10 kB)
# Downloading semantic_link_functions_geopandas-0.12.1-py3-none-any.whl (4.0 kB)
# Downloading semantic_link_functions_holidays-0.12.1-py3-none-any.whl (4.2 kB)
# Downloading semantic_link_functions_meteostat-0.12.1-py3-none-any.whl (4.5 kB)
# Downloading semantic_link_functions_phonenumbers-0.12.1-py3-none-any.whl (4.3 kB)
# Downloading semantic_link_functions_validators-0.12.1-py3-none-any.whl (4.8 kB)
# Downloading semantic_link_sempy-0.12.1-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 41.8 MB/s eta 0:00:0000:0100:01
# Downloading fabric_analytics_sdk-0.0.1-py3-none-any.whl (34 kB)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 4.4 MB/s eta 0:00:00
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.4/338.4 kB 13.3 MB/s eta 0:00:00
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 32.5 MB/s eta 0:00:00
# Downloading meteostat-1.7.6-py3-none-any.whl (33 kB)
# Downloading phonenumbers-9.0.16-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 62.5 MB/s eta 0:00:00:00:01
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.1 MB/s eta 0:00:00
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading pyogrio-0.11.1-cp311-cp311-manylinux_2_28_x86_64.whl (27.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 72.8 MB/s eta 0:00:00:00:0100:01
# Downloading pyproj-3.7.2-cp311-cp311-manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 105.5 MB/s eta 0:00:0000:0100:01
# Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.0 MB/s eta 0:00:00:00:01
# Downloading fabric_analytics_notebook_plugin-0.0.1-py3-none-any.whl (20 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: phonenumbers, xyzservices, validators, shapely, pyproj, pyogrio, branca, meteostat, mapclassify, geopandas, folium, fabric-analytics-sdk, fabric-analytics-notebook-plugin, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.11.0
#     Uninstalling semantic-link-sempy-0.11.0:
#       Successfully uninstalled semantic-link-sempy-0.11.0
# Successfully installed branca-0.8.2 fabric-analytics-notebook-plugin-0.0.1 fabric-analytics-sdk-0.0.1 folium-0.20.0 geopandas-1.1.1 mapclassify-2.10.0 meteostat-1.7.6 phonenumbers-9.0.16 pyogrio-0.11.1 pyproj-3.7.2 semantic-link-0.12.1 semantic-link-functions-geopandas-0.12.1 semantic-link-functions-holidays-0.12.1 semantic-link-functions-meteostat-0.12.1 semantic-link-functions-phonenumbers-0.12.1 semantic-link-functions-validators-0.12.1 semantic-link-sempy-0.12.1 shapely-2.1.2 validators-0.35.0 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list | grep -i semantic-link-sempy
# Out:
# semantic-link-sempy                0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Scale Up in Pure Python Notebook
# ### Options are 2,4,8,16 (32 and 64)
# #### **Note: Increases start-up time and resources used**
# #### **Default is trying to get you in and working quickly**
# https://learn.microsoft.com/en-us/fabric/data-engineering/using-python-experience-on-notebook#session-configuration-magic-command

# %%
# %%configure - f
# {
#     "vCores": 4
# }

# %%
import sempy.fabric as fabric

from sempy.relationships import plot_relationship_metadata
from sempy.relationships import find_relationships
from sempy.fabric import list_relationship_violations

# %% [markdown]
# ### List Semantic Models (datasets)

# %%
df = fabric.list_datasets()
display(df)

# %%
modeltables = fabric.list_tables(dataset='Hyrule10K')
display(modeltables)

# %%
hyruleSemanticModel = "Hyrule10K"
relationships = fabric.list_relationships(hyruleSemanticModel)
relationships
# Out:
#   Multiplicity From Table  From Column  To Table    To Column  Active  \
# 0          m:1      Sales   ProductKey   Product   ProductKey    True
# 1          m:1      Sales  CustomerKey  Customer  CustomerKey    True
# 2          m:1      Sales     StoreKey     Store     StoreKey    True
# 3          m:1      Sales   Order Date      Date         Date    True
#
#   Cross Filtering Behavior Security Filtering Behavior Join On Date Behavior  \
# 0             OneDirection                OneDirection           DateAndTime
# 1             OneDirection                OneDirection           DateAndTime
# 2             OneDirection                OneDirection           DateAndTime
# 3             OneDirection                OneDirection           DateAndTime
#
#    Rely On Referential Integrity  State       Modified Time  \
# 0                          False  Ready 2025-03-05 04:49:47
# 1                          False  Ready 2025-03-05 04:49:47
# 2                          False  Ready 2025-03-05 04:49:47
# 3                          False  Ready 2025-03-05 04:49:47
#
#                       Relationship Name
# 0  a8b50698-7055-48e7-8916-a23af06d860e
# 1  ac5d83e9-674f-414c-a76b-be917eba1763
# 2  9d669e2e-8c9e-4c12-b20e-f93d76a69879
# 3  7a4484ff-5842-46e9-8589-8e6cf9f5b714

# %%
plot_relationship_metadata(relationships)

# %%
hyruledate_semanticmodel = "Hyrule10K_WithAutoDate"
relationships_date = fabric.list_relationships(hyruledate_semanticmodel)
relationships_date
# Out:
#   Multiplicity From Table    From Column  \
# 0          m:1      Sales     ProductKey
# 1          m:1      Sales    CustomerKey
# 2          m:1      Sales       StoreKey
# 3          m:1      Sales     Order Date
# 4          m:1      Sales  Delivery Date
# 5          m:1      Store      Open Date
# 6          m:1      Store     Close Date
# 7          m:1       Date           Date
# 8          m:1   Customer       Birthday
#
#                                             To Table    To Column  Active  \
# 0                                            Product   ProductKey    True
# 1                                           Customer  CustomerKey    True
# 2                                              Store     StoreKey    True
# 3                                               Date         Date    True
# 4  LocalDateTable_1a151f76-9243-495e-8cca-934dd16...         Date    True
# 5  LocalDateTable_b4b67843-943d-4c6b-8ce4-69d8e3d...         Date    True
# 6  LocalDateTable_91db0935-ef50-4984-95fa-39a3fd6...         Date    True
# 7  LocalDateTable_b56160cf-47a9-4629-a90b-c38e46b...         Date    True
# 8  LocalDateTable_6ba37e3b-3ddd-4942-bdf8-35e48ae...         Date    True
#
#   Cross Filtering Behavior Security Filtering Behavior Join On Date Behavior  \
# 0             OneDirection                OneDirection           DateAndTime
# 1             OneDirection                OneDirection           DateAndTime
# 2             OneDirection                OneDirection           DateAndTime
# 3             OneDirection                OneDirection           DateAndTime
# 4             OneDirection                OneDirection          DatePartOnly
# 5             OneDirection                OneDirection          DatePartOnly
# 6             OneDirection                OneDirection          DatePartOnly
# 7             OneDirection                OneDirection          DatePartOnly
# 8             OneDirection                OneDirection          DatePartOnly
#
#    Rely On Referential Integrity  State       Modified Time  \
# 0                          False  Ready 2025-03-05 04:49:47
# 1                          False  Ready 2025-03-05 04:49:47
# 2                          False  Ready 2025-03-05 04:49:47
# 3                          False  Ready 2025-03-05 04:49:47
# 4                          False  Ready 2025-10-13 13:28:42
# 5                          False  Ready 2025-10-13 13:28:42
# 6                          False  Ready 2025-10-13 13:28:42
# 7                          False  Ready 2025-10-13 13:28:42
# 8                          False  Ready 2025-10-13 13:28:42
#
#                       Relationship Name
# 0  a8b50698-7055-48e7-8916-a23af06d860e
# 1  ac5d83e9-674f-414c-a76b-be917eba1763
# 2  9d669e2e-8c9e-4c12-b20e-f93d76a69879
# 3  7a4484ff-5842-46e9-8589-8e6cf9f5b714
# 4  92faece0-5f1a-4a51-8792-12c6a4ad68be
# 5  a9ad5315-665a-49be-9a33-86ffd9fbd09e
# 6  460f6d5d-ffbb-4340-8835-fe1761ff4158
# 7  e3bdc768-687f-4768-a8ba-d17a56d0512a
# 8  565df8ee-a814-48f4-9147-96d5df94619c

# %% [markdown]
# ## See the invisible (hidden)

# %%
hyruledate_semanticmodel = "Hyrule10K_WithAutoDate"
relationships_date = fabric.list_relationships(hyruledate_semanticmodel)
plot_relationship_metadata(relationships_date)

# %% [markdown]
# ### Run DAX code against Semantic Modal

# %%
# %load_ext sempy

# %%
# %%dax "Hyrule10K" -w "Nashville2025_SLL"
#
# EVALUATE
# SUMMARIZECOLUMNS(
#     'Product'[Brand],
#    'Date'[Month Short],
#    'Date'[Year],
#    "Sales Amount",
#     CALCULATE([Sales Amount]))
# Out:
#            Product[Brand] Date[Month Short]  Date[Year]  [Sales Amount]
# 0                 Contoso               Jan        2018      112550.619
# 1    Wide World Importers               Jan        2018      138872.331
# 2       Northwind Traders               Jan        2018        7972.614
# 3         Adventure Works               Jan        2018      155530.706
# 4        Southridge Video               Jan        2018        33836.24
# ..                    ...               ...         ...             ...
# 373              Fabrikam               Dec        2019        44689.78
# 374             Proseware               Dec        2019        49316.57
# 375              A. Datum               Dec        2019          8590.4
# 376     The Phone Company               Dec        2019         84677.0
# 377         Tailspin Toys               Dec        2019         2767.85
#
# [378 rows x 4 columns]

# %% [markdown]
# ### **If you want to do more with these functions, you need to write all the code**
# ### **Powershell**
# ### **What if there was another way**
# ### **That is where Semantic Link Labs comes in**
