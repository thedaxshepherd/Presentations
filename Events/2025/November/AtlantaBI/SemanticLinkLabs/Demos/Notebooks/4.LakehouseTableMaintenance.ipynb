# %% [markdown]
# # Table Maintenance

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 9, Finished, Available, Finished)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 8.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 16.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 33.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Not uninstalling azure-core at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-53cd1e57-bf64-43f3-b6e1-eb94c1b62c8c
#     Can't uninstall 'azure-core'. No files were found to uninstall.
#   Attempting uninstall: semantic-link-sempy
# ...

# %%
import sempy_labs as labs
import sempy_labs.lakehouse as lakehouse
# Out:
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 11, Finished, Available, Finished)

# %% [markdown]
# ### Vacuum

# %%
lakehouse.vacuum_lakehouse_tables(
    tables =["datasets", "raft_rentals"],
    lakehouse="lh_lakehylia",
    workspace="AtlantaBI_SLL",
    retain_n_hours=168
)
# Out:
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 18, Finished, Available, Finished)
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 19, Finished, Available, Finished)
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 22, Finished, Available, Finished)

# %% [markdown]
# ### Optimize Tables
# ###

# %%
lakehouse.optimize_lakehouse_tables(
    tables=["datasets"],
    lakehouse="lh_lakehylia",
    workspace="AtlantaBI_SLL"

)

# %% [markdown]
# ### All in one - wrapper for API

# %%
lakehouse.run_table_maintenance(
    table_name ="datasets",
    optimize=True,
    v_order=False,
    vacuum=True,
    retention_period='10:00:00:00',
    lakehouse="lh_lakehylia",
    workspace="AtlantaBI_SLL"
)
# Out:
# StatementMeta(, f0abbe97-1294-4658-8cd9-6f6f173035fc, 13, Finished, Available, Finished)
# ⌛ The table maintenance job for the 'datasets' table in the 'lh_lakehylia' lakehouse within the 'AtlantaBI_SLL' workspace has been initiated.
# 🟢 The table maintenance job for the 'datasets' table in the 'lh_lakehylia' lakehouse within the 'AtlantaBI_SLL' workspace has succeeded.
# Empty DataFrame
# Columns: [Job Instance Id, Item Id, Job Type, Invoke Type, Status, Root Activity Id, Start Time UTC, End Time UTC, Error Message]
# Index: []
