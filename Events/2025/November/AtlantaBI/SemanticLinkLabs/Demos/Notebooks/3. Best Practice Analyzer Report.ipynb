# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, 6c6212fd-c3dc-48a2-ad8e-ce24b7081f09, 7, Finished, Available, Finished)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 18.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 60.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Not uninstalling azure-core at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-f5ee9cd9-43ba-4e15-87f2-ad5d15332735
#     Can't uninstall 'azure-core'. No files were found to uninstall.
#   Attempting uninstall: semantic-link-sempy
# ...

# %% [markdown]
# ### Import the library and necessary packages

# %%
import sempy_labs as labs
import sempy_labs.report as rep

dataset = 'Hyrule10K' # Enter your dataset name
workspace = 'AtlantaBI_SLL' # Enter your workspace name (if set to None it will use the workspace in which the notebook is running)
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 22, Finished, Available, Finished)

# %% [markdown]
# ### Collect semantic model Best Practice Analyzer stats

# %% [markdown]
# ## **Issue with Lakehouse Schemas**

# %% [markdown]
# #### Collect stats for all semantic models within a single workspace

# %%
labs.run_model_bpa_bulk(workspace=workspace)
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 28, Finished, Available, Finished)
# ⌛ Collecting Model BPA stats for the 'Hyrule10K' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Collecting Model BPA stats for the 'Hyrule10K_WithAutoDate' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K_WithAutoDate' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Collecting Model BPA stats for the 'Hyrule10K_RI' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K_RI' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Saving the Model BPA results of the 'AtlantaBI_SLL' workspace to the 'modelbparesults' within the lakehouse attached to this notebook...
# ...

# %% [markdown]
# #### Collect stats for all semantic models within a list of workspaces

# %%
labs.run_model_bpa_bulk(workspace=['Workspace 1', 'Workspace 2'])

# %% [markdown]
# #### Collect stats for all semantic models within all accessible workspaces

# %%
labs.run_model_bpa_bulk(workspace=None)

# %% [markdown]
# #### Create a Direct Lake semantic model (called 'ModelBPA') for analyzing the Best Practice Analyzer results

# %%
labs.create_model_bpa_semantic_model()
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 30, Finished, Available, Finished)
# 🟢 The 'ModelBPA' semantic model was created within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'BPAResults' table has been added to the 'ModelBPA' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'modelbparesults' partition has been added to the 'BPAResults' table in the 'ModelBPA' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'Capacity_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'Capacity_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'Workspace_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'AtlantaBI_SLL' workspace.
# ...

# %% [markdown]
# #### Create a Power BI report called 'ModelBPA' based semantic model created in the previous cell, which can be used to analyze the Best Practice Analyzer results

# %%
rep.create_model_bpa_report()
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 31, Finished, Available, Finished)
# 🟢 Succesfully created the 'ModelBPA' report within the 'AtlantaBI_SLL' workspace.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> The 'BPAReport' Power BI report is located within the workspace in which the default lakehouse attached to this notebook resides. Navigate to this workspace to open the report and view the Best Practice Analyzer results.
# </div>
#
# Going forward, you just need to run the 'run_model_bpa_bulk' function which will append BPA results to the 'modelbparesults' delta table in your lakehouse. Since the 'BPAModel' semantic model is in Direct Lake mode, the data will appear in the semantic model and report automatically without any need for processing the semantic model.

# %%
import sempy_labs.report as rep

rep.launch_report(report="ModelBPA", workspace="AtlantaBI_SLL")
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 33, Finished, Available, Finished)
# Report()
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 34, Finished, Available, Finished)
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 35, Finished, Available, Finished)
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 36, Finished, Available, Finished)
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 37, Finished, Available, Finished)
# StatementMeta(, 3427331b-55e7-42da-bfef-82659e99080c, 3, Finished, Available, Finished)
# No such comm: 80744c1e8c4142c3b2b6693b89394321
# No such comm: 1c8a801e997a4875bef404fed13d1660
# StatementMeta(, 3427331b-55e7-42da-bfef-82659e99080c, 4, Finished, Available, Finished)
# No such comm: 1c8a801e997a4875bef404fed13d1660

# %%
labs.run_model_bpa_bulk(workspace=workspace)
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 32, Finished, Available, Finished)
# ⌛ Collecting Model BPA stats for the 'Hyrule10K' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Collecting Model BPA stats for the 'Hyrule10K_WithAutoDate' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K_WithAutoDate' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Collecting Model BPA stats for the 'Hyrule10K_RI' semantic model within the 'AtlantaBI_SLL' workspace.
# 🟢 Collected Model BPA stats for the 'Hyrule10K_RI' semantic model within the 'AtlantaBI_SLL' workspace.
# ⌛ Saving the Model BPA results of the 'AtlantaBI_SLL' workspace to the 'modelbparesults' within the lakehouse attached to this notebook...
# ...
