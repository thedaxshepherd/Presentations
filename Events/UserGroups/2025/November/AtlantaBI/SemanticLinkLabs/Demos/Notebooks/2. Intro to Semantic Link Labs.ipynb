# %% [markdown]
# # Intro to Semantic Link Labs

# %% [markdown]
# #### Have to use !pip for high concurrency sessions
# ### Instead of %pip

# %%
# !pip list | grep semantic-link
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 7, Finished, Available, Finished)
# semantic-link-labs                 0.12.6
# semantic-link-sempy                0.11.0

# %%
# !pip install semantic-link-labs
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 3, Finished, Available, Finished)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 7.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 30.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Uninstalling azure-core-1.30.2:
#       Successfully uninstalled azure-core-1.30.2
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.11.0
#     Uninstalling semantic-link-sempy-0.11.0:
#       Successfully uninstalled semantic-link-sempy-0.11.0
# ...

# %%
# !pip list | grep semantic-link
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 4, Finished, Available, Finished)
# semantic-link-labs                 0.12.6
# semantic-link-sempy                0.12.2

# %%
import sempy.fabric as fabric
import sempy_labs as labs
import sempy_labs.lakehouse as lake
import sempy_labs.report as rep
from sempy_labs import migration, directlake, admin, graph, theme, mirrored_azure_databricks_catalog, ml_model, variable_library
from sempy_labs.tom import connect_semantic_model
from sempy_labs.report import connect_report
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 7, Finished, Available, Finished)

# %% [markdown]
# ### Save to Table

# %%
datasets = fabric.list_datasets()
sparkdatasets = spark.createDataFrame(datasets)
sparkdatasets_columns = sparkdatasets.withColumnsRenamed(
  {"Dataset Name": "DatasetName", "Dataset ID": 
  "DatasetID", "Created Timestamp": "CreatedTimestamp", "Last Update": "LastUpdate"}
  )
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 10, Finished, Available, Finished)

# %%
sparkdatasets_columns.write\
  .mode("overwrite")\
  .option("overwriteSchema", "true")\
  .saveAsTable("lh_lakehylia.datasets")
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 11, Finished, Cancelled, Cancelled)

# %% [markdown]
# ### Read from table

# %%
df = spark.sql("SELECT * FROM lh_lakehylia.datasets LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ac8ffea2-4550-4995-8841-537917838812)

# %% [markdown]
# ### Power BI Report

# %%
ds = "Hyrule10K"
ws = "AtlantaBI_SLL"
import sempy_labs.report as rep
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 14, Finished, Available, Finished)

# %%
rep.launch_report(report="Hyrule10K", workspace=ws)
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 15, Finished, Available, Finished)
# Report()
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 16, Finished, Available, Finished)
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 17, Finished, Available, Finished)
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 18, Finished, Available, Finished)
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 19, Finished, Available, Finished)

# %% [markdown]
# ### Save semantic Model to BIM File

# %%
df = labs.get_semantic_model_bim(dataset="Hyrule10K",  save_to_file_name="BimFiles/hyrule10k.bim")
# Out:
# StatementMeta(, 74fe0b75-ea17-4d3b-9c92-326d11811535, 17, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df = labs.get_semantic_model_bim(dataset="Hyrule10K",  save_to_file_name="BimFiles/hyrule10k.bim")
#
# NameError: name 'labs' is not defined

# %% [markdown]
# ## Helper Notebooks

# %% [markdown]
# ### Can add Notebooks to a folder
# ### **Note: Folder and uniqueness**
# Currently, overwrite for notebooks not supported

# %%
import sempy_labs as labs
import requests
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 20, Finished, Available, Finished)

# %%
workspace_name = 'AtlantaBI_SLL' # Update this to the workspace in which you want to save the notebooks
api_url = "https://api.github.com/repos/microsoft/semantic-link-labs/contents/notebooks"
response = requests.get(api_url)
files = response.json()
notebook_files = {file['name'][:-6]: file['html_url'] for file in files if file['name'].endswith('.ipynb')}

for file_name, file_url in notebook_files.items():
    labs.import_notebook_from_web(notebook_name=file_name, url=file_url, workspace=workspace_name, overwrite=True, folder='SLL_HelperNotebooks')
# Out:
# StatementMeta(, 56745ece-c4b7-47b5-ad05-d9b2021c7708, 21, Finished, Available, Finished)
# 🟢 The 'Best Practice Analyzer Report' Notebook has been successfully created within the 'AtlantaBI_SLL' workspace.
# 🟢 The 'Capacity Migration' Notebook has been successfully created within the 'AtlantaBI_SLL' workspace.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
# ℹ️ Overwrite of notebooks is currently not supported.
