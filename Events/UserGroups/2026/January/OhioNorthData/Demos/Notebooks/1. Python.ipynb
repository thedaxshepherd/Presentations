# %% [markdown]
# # Intro to Python

# %% [markdown]
# ## Let's start with the mandatory 'Hello World' – because tradition matters!

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Install library
# - ### Example Pandas, Polars, DuckDB

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy<2,>=1.21 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Install if not installed, Upgrade if installed and Upgrade dependencies

# %%
# %pip install -U matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (3.8.2)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.8-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 44.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.2
#     Uninstalling matplotlib-3.8.2:
#       Successfully uninstalled matplotlib-3.8.2
# Successfully installed matplotlib-3.10.8
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Is Library installed?

# %% [markdown]
# #### Specific library with detail

# %%
# %pip show duckdb
# Out:
# Name: duckdb
# Version: 1.2.2
# Summary: DuckDB in-process database
# Home-page: https://www.duckdb.org
# Author:
# Author-email:
# License: MIT
# Location: /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### List installed libraries

# %%
# %pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            2.3.1
# adlfs                              2023.4.0
# aiohappyeyeballs                   2.6.1
# aiohttp                            3.11.11
# aiosignal                          1.4.0
# alembic                            1.16.5
# altair                             5.4.1
# annotated-types                    0.7.0
# anyio                              4.10.0
# archspec                           0.2.5
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               25.1.0
# arrow                              1.3.0
# astor                              0.8.1
# asttokens                          3.0.0
# async-lru                          2.0.5
# atpublic                           5.1
# attrs                              25.3.0
# azure-common                       1.1.28
# azure-core                         1.29.4
# azure-datalake-store               0.0.53
# azure-identity                     1.17.1
# azure-keyvault-secrets             4.7.0
# azure-storage-blob                 12.22.0
# azure-storage-file-datalake        12.12.0
# babel                              2.17.0
# bcrypt                             4.3.0
# beautifulsoup4                     4.12.2
# bleach                             6.2.0
# blinker                            1.9.0
# boltons                            25.0.0
# boto3                              1.35.99
# botocore                           1.35.99
# Brotli                             1.1.0
# cached-property                    1.5.2
# cachetools                         5.5.2
# catboost                           1.2.5
# certifi                            2024.7.4
# cffi                               1.17.1
# charset-normalizer                 3.4.3
# chat-magics                        0.1.25.2.28
# chat-magics-fabric                 0.2.0.25.2.28
# click                              8.2.1
# cloudpickle                        3.1.1
# clr_loader                         0.2.7.post0
# cmdstanpy                          1.2.5
# colorama                           0.4.6
# colorlog                           6.9.0
# comm                               0.2.3
# conda-package-handling             2.4.0
# conda_package_streaming            0.12.0
# contourpy                          1.3.3
# convertdate                        2.4.0
# cryptography                       45.0.6
# cycler                             0.12.1
# dash                               3.2.0
# dash-core-components               2.0.0
# dash-cytoscape                     0.2.0
# dash_html_components               2.0.0
# dash-table                         5.0.0
# databricks-sdk                     0.64.0
# debugpy                            1.8.16
# decorator                          5.2.1
# defusedxml                         0.7.1
# deltalake                          0.18.2
# Deprecated                         1.2.18
# dill                               0.4.0
# distlib                            0.4.0
# distro                             1.9.0
# dnspython                          2.7.0
# docker                             7.0.0
# ds_copilot                         0.1.25.2.28
# duckdb                             1.2.2
# email-validator                    2.3.0
# et_xmlfile                         2.0.0
# exceptiongroup                     1.3.0
# executing                          2.2.0
# fabric-connection                  0.2.0
# fastapi                            0.116.1
# fastapi-cli                        0.0.8
# fastjsonschema                     2.21.2
# filelock                           3.11.0
# FLAML                              2.3.6.post1
# Flask                              3.1.2
# fluent-logger                      0.10.0
# fonttools                          4.59.2
# fqdn                               1.5.1
# frozenlist                         1.7.0
# fsspec                             2023.10.0
# fsspec_wrapper                     0.1.15
# geographiclib                      2.1
# geopy                              2.4.1
# gevent                             25.5.1
# gitdb                              4.0.12
# GitPython                          3.1.45
# gmpy2                              2.2.1
# google-auth                        2.40.3
# graphviz                           0.20.3
# greenlet                           3.2.4
# gson                               0.0.4
# h11                                0.16.0
# h2                                 4.2.0
# hcrystalball                       0.1.10
# holidays                           0.79
# hpack                              4.1.0
# html5lib                           1.1
# httpcore                           1.0.9
# httptools                          0.6.4
# httpx                              0.28.1
# hyperframe                         6.1.0
# ibis-framework                     9.4.0
# idna                               3.10
# imageio                            2.33.1
# importlib_metadata                 7.0.2
# importlib_resources                6.5.2
# interpret                          0.6.0
# interpret-core                     0.6.0
# invoke                             2.2.0
# ipykernel                          6.30.1
# ipython                            8.20.0
# ipywidgets                         8.1.1
# isodate                            0.6.1
# isoduration                        20.11.0
# itsdangerous                       2.2.0
# jedi                               0.19.2
# Jinja2                             3.1.6
# jmespath                           1.0.1
# joblib                             1.5.2
# json-tricks                        3.17.3
# json5                              0.12.1
# jsonpatch                          1.33
# jsonpointer                        3.0.0
# jsonschema                         4.25.1
# jsonschema-specifications          2025.4.1
# jupyter                            1.1.1
# jupyter_client                     8.6.3
# jupyter-console                    6.6.3
# jupyter_core                       5.8.1
# jupyter-events                     0.12.0
# jupyter-lsp                        2.3.0
# jupyter_server                     2.15.0
# jupyter_server_terminals           0.5.3
# jupyter-ui-poll                    1.0.0
# jupyterlab                         4.4.6
# jupyterlab_pygments                0.3.0
# jupyterlab_server                  2.27.3
# jupyterlab_widgets                 3.0.15
# kiwisolver                         1.4.9
# lark                               1.2.2
# liac-arff                          2.5.0
# libmambapy                         2.3.2
# lightgbm                           4.6.0
# llvmlite                           0.44.0
# lunardate                          0.2.2
# lxml                               5.1.0
# Mako                               1.3.10
# Markdown                           3.5.1
# markdown-it-py                     4.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.10.8
# matplotlib-inline                  0.1.7
# mdurl                              0.1.2
# menuinst                           2.3.1
# mistune                            3.1.3
# mlflow-skinny                      2.22.0
# mpmath                             1.3.0
# msal                               1.33.0
# msal-extensions                    1.3.1
# msgpack                            1.1.1
# multidict                          6.6.3
# multiprocess                       0.70.18
# munkres                            1.1.4
# mypy                               1.4.1
# mypy-extensions                    1.0.0
# narwhals                           2.2.0
# nbclient                           0.10.2
# nbconvert                          7.16.6
# nbformat                           5.10.4
# nest_asyncio                       1.6.0
# networkx                           3.5
# nltk                               3.9.1
# nni                                3.0
# notebook                           7.4.5
# notebook_shim                      0.2.4
# notebookutils                      2.0.9.20251017.2
# numba                              0.61.2
# numpy                              1.26.4
# nvidia-ml-py                       13.580.65
# openpyxl                           3.1.2
# opentelemetry-api                  1.27.0
# opentelemetry-sdk                  1.27.0
# opentelemetry-semantic-conventions 0.48b0
# optuna                             3.6.1
# overrides                          7.7.0
# packaging                          24.2
# pandas                             2.1.4
# pandasnet                          1.0
# pandasql                           0.7.3
# pandocfilters                      1.5.0
# paramiko                           4.0.0
# parso                              0.8.5
# parsy                              2.1
# pathlib                            1.0.1
# pathos                             0.3.4
# patsy                              1.0.1
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.3.0
# pip                                23.3.2
# platformdirs                       4.4.0
# plotly                             6.3.0
# pluggy                             1.6.0
# ply                                3.11
# polars                             1.6.0
# portalocker                        3.2.0
# powerbiclient                      3.1.1
# pox                                0.3.6
# ppft                               1.7.7
# prettytable                        3.9.0
# prometheus_client                  0.22.1
# prompt_toolkit                     3.0.52
# propcache                          0.3.1
# prophet                            1.1.5
# prose.pandas2pyspark               10.5.0rc2024121001
# prose.suggestions                  10.4.1
# protobuf                           5.29.3
# psutil                             7.0.0
# ptyprocess                         0.7.0
# pure_eval                          0.2.3
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyarrow-hotfix                     0.7
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.2
# pycairo                            1.28.0
# pycosat                            0.6.6
# pycparser                          2.22
# pydantic                           2.11.7
# pydantic_core                      2.33.2
# Pygments                           2.19.2
# PyGObject                          3.50.0
# PyJWT                              2.8.0
# pyluach                            2.2.0
# PyMeeus                            0.5.12
# PyNaCl                             1.5.0
# pyodbc                             4.0.39
# pyOpenSSL                          25.1.0
# pyparsing                          3.2.3
# pyperclip                          1.8.2
# PyQt5                              5.15.11
# PyQt5_sip                          12.17.0
# PySocks                            1.7.1
# pyspark                            3.5.1.5.4.20240407
# python-dateutil                    2.9.0.post0
# python-dotenv                      1.1.1
# python-json-logger                 2.0.7
# python-multipart                   0.0.20
# pythonnet                          3.0.3
# PythonWebHDFS                      0.2.3
# pytz                               2025.2
# pyu2f                              0.1.5
# PyYAML                             6.0.2
# pyzmq                              27.0.2
# redis                              6.4.0
# referencing                        0.36.2
# regex                              2023.12.25
# requests                           2.32.5
# responses                          0.25.8
# retrying                           1.4.2
# rfc3339_validator                  0.1.4
# rfc3986-validator                  0.1.1
# rfc3987-syntax                     1.1.0
# rgf-python                         3.12.0
# rich                               13.9.4
# rich-toolkit                       0.15.0
# rouge_score                        0.1.2
# rpds-py                            0.27.1
# rsa                                4.9.1
# ruamel.yaml                        0.18.5
# ruamel.yaml.clib                   0.2.7
# s3transfer                         0.10.4
# SALib                              1.5.1
# schema                             0.7.7
# scikit-learn                       1.5.0
# scipy                              1.16.1
# semantic-link-sempy                0.11.0
# Send2Trash                         1.8.3
# seqeval                            1.2.2
# setuptools                         80.9.0
# shap                               0.48.0
# shellingham                        1.5.4
# simplejson                         3.20.1
# sip                                6.10.0
# six                                1.16.0
# slicer                             0.0.8
# smmap                              5.0.2
# sniffio                            1.3.1
# soupsieve                          2.8
# SQLAlchemy                         2.0.43
# sqlglot                            25.18.0
# sqlparse                           0.5.3
# stack_data                         0.6.3
# stanio                             0.5.1
# starlette                          0.47.3
# statsmodels                        0.14.5
# sympy                              1.14.0
# synapseml-mlflow                   1.0.31
# synapseml_utils                    1.1.6.post1
# tenacity                           9.0.0
# terminado                          0.18.1
# thop                               0.1.1.post2209072238
# threadpoolctl                      3.6.0
# tinycss2                           1.4.0
# toml                               0.10.2
# tomli                              2.2.1
# toolz                              0.12.1
# torch                              2.2.2
# tornado                            6.5.2
# tqdm                               4.66.4
# traitlets                          5.14.3
# truststore                         0.10.3
# typed-ast                          1.5.5
# typeguard                          4.1.2
# typer                              0.16.1
# typer-slim                         0.16.1
# types-python-dateutil              2.9.0.20250822
# typing_extensions                  4.15.0
# typing-inspection                  0.4.1
# typing_utils                       0.1.0
# tzdata                             2025.2
# unicodedata2                       16.0.0
# uri-template                       1.3.0
# urllib3                            2.2.2
# uvicorn                            0.35.0
# uvloop                             0.21.0
# virtualenv                         20.29.2
# watchfiles                         1.1.0
# wcwidth                            0.2.13
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# websockets                         15.0.1
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 4.0.14
# workalendar                        17.0.0
# wrapt                              1.17.3
# xgboost                            1.7.6
# yarl                               1.20.1
# zipp                               3.23.0
# zope.event                         5.1.1
# zope.interface                     7.2
# zstandard                          0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### List and filter using grep

# %%
# %pip list | grep duck
# Out:
# duckdb                             1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### List that we can display and filter

# %%
# Method that gives us more options like displaying and filtering
# uses newer method and not ones that are deprecated

from importlib.metadata import distributions
import pandas as pd

packages = [(dist.metadata['Name'], dist.version) for dist in distributions()]
# Give human readable column names
df = pd.DataFrame(packages, columns=['Package', 'Version'])
display(df.sort_values('Package'))

# %% [markdown]
# ### Import library - alias friendly shorter names (preference)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# ## Python is Object Orientated

# %% [markdown]
# ### Variables

# %%
# Code for Variables

my_variable = 100
print(my_variable)
# Out:
# 100

# %%
hello = "Hello World!"
print(hello)
# Out:
# Hello World!

# %% [markdown]
# ### Functions

# %%
# Code for Functions
# We have already seen one: print()
# We apply this over the object
# Here is another

fruit = 'apple'
fruit_length = len(fruit)
print(fruit_length)
# Out:
# 5

# %%
# We can create our own

def double(x):
    return x * 2

print(double(10))
# Out:
# 20

# %% [markdown]
# ### Methods - part of the object

# %%
# Code for Methods

name = "DAX Shepherd"
lowername = name.lower()    # Method to convert to lowercase
lowername.startswith("d")
# Out:
# True

# %% [markdown]
# ### Method Chaining

# %%
# Chaining

name = "DAX Shepherd"

#First convert to lowercase and then check if it start with lowercase "d"

name.lower().startswith("d")
# Out:
# True

# %% [markdown]
# ### Chaining across lines

# %% [markdown]
# ### **Method 1: Parenthesis '()'**

# %%
# Chaining across lines

# Very common in PySpark code
# Allows you to think about each transformtion you are doing

# Use the parenthesis '()'

name = "DAX Shepherd"

result = (
    name
    .lower()
    .startswith("d")
)

# %% [markdown]
# ### **Method 2: Backslash '\\'**

# %%
# Chaining across lines

# Very common in PySpark code
# Allows you to think about each transformation you are doing

# Use the backslash '\'

name = "DAX Shepherd"

name \
    .lower() \
    .startswith("d")
# Out:
# True

# %% [markdown]
# ### Accessing data from Pure Python notebook
# - #### Drag table over
# - #### Will see more in PySpark Notebook

# %%
# Mount external lakehouse  "The_Anvil" into specified local path.
notebookutils.fs.mount("abfss://f651a469-ce2b-4682-af21-71fcc98961b0@onelake.dfs.fabric.microsoft.com/3e9ebe3d-fec4-4b73-80cd-4febd0a00762", "/lakehouse/The_Anvil")
import pandas as pd
# Load data into pandas DataFrame from notebookutils.fs.getMountPath('/lakehouse/The_Anvil/') + "Files/Legos/sets.csv"
df = pd.read_csv(notebookutils.fs.getMountPath('/lakehouse/The_Anvil/') + "Files/Legos/sets.csv")
display(df)

# %%
from deltalake import DeltaTable, write_deltalake
table_path = 'abfss://f651a469-ce2b-4682-af21-71fcc98961b0@onelake.dfs.fabric.microsoft.com/3e9ebe3d-fec4-4b73-80cd-4febd0a00762/Tables/sets' 
storage_options = {"bearer_token": notebookutils.credentials.getToken('storage'), "use_fabric_endpoint": "true"}
dt = DeltaTable(table_path, storage_options=storage_options)
limited_data = dt.to_pyarrow_dataset().head(1000).to_pandas()
display(limited_data)

# Write data frame to Lakehouse
# write_deltalake(table_path, limited_data, mode='overwrite')

# If the table is too large and might cause an Out of Memory (OOM) error,
# you can try using the code below. However, please note that delta_scan with default lakehouse is currently in preview.
# import duckdb
# display(duckdb.sql("select * from delta_scan('/lakehouse/default/Tables/dbo/bigdeltatable') limit 1000 ").df())

# %%
import duckdb
display(duckdb.sql("select * from delta_scan('/lakehouse/default/Tables/sets') limit 1000 ").df())

# %% [markdown]
# ### Using DuckDB Example - adding our own SQL Code

# %%
import duckdb

duckdb.sql(
    """
    SELECT 
        set_num AS 'Set #',
        name AS 'Set Name',
        year AS 'Year'
    FROM delta_scan('/lakehouse/default/Tables/sets')
    WHERE name LIKE 'Ninjago%'
        AND year = '2022'
    LIMIT 10
    """
).df()
# Out:
#              Set #                                   Set Name  Year
# 0     0003977811-1                Ninjago: Book of Adventures  2022
# 1  9781780558752-1                      Ninjago: Sssnake Time  2022
# 2        5007553-1  Ninjago: Build And Stick: NINJAGO Dragons  2022
# 3  9781760508807-1     Ninjago Legacy: Action in NINJAGO City  2022
# 4  9783960807230-1                       Ninjago: Rätselbox 3  2022
# 5  9786180145809-1                       Ninjago: Ninja Style  2022
# 6         342140-1              Ninjago Cole Minifigure Plush  2022
# 7         PILLOW-3    Ninjago: Lloyd Minifigure Cuddle Pillow  2022
# 8        4040873-1                Ninjago: Book of Adventures  2022
# 9  9783960806295-1                      Ninjago: Stickerspass  2022

# %% [markdown]
# # What happens when your data is too big??

# %% [markdown]
# ##
